# %%
import pandas as pd


data = pd.read_csv('porcentaje_habitaciones_precio_comunidad.csv')


data['suma_total'] = data['Conteo_limpio'] + data['habitaciones'] + data['descuento']


data['porcentaje_habitaciones'] = (data['habitaciones'] / data['suma_total']) * 100


data['porcentaje_descuento'] = (data['descuento'] / data['suma_total']) * 100


data.to_csv('resultado_con_porcentajes_total.csv', index=False)


print(data)
# Out:
#                Comunidad  Conteo_limpio  habitaciones  descuento  \
# 0              andalucia            100            61         19
# 1                 aragon             78            72         14
# 2               asturias             92            55         13
# 3               baleares            119            48          8
# 4              cantabria             89            63         10
# 5     castilla_la_mancha             97            88         14
# 6        castilla_y_leon             89            76         27
# 7               cataluña             92            76         18
# 8                  ceuta             86            46         13
# 9   comunidad_valenciana            133            49         12
# 10           extremadura             71            86         17
# 11               galicia             82            67         13
# 12              la_rioja             75            82          9
# ...
